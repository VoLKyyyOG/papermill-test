# %%
import papermill as pm

# %% [markdown]
# - `gender`: `["male", "female"]`
# - `edu`: `["associate's degree", "bachelor's degree", 'high school', "master's degree", 'some college', 'some high school']`

# %%
pm.execute_notebook('papermill.ipynb',
                    'papermill_output.ipynb',
                    parameters={
                        'gender': "female",
                        'edu': "master's degree"
                    })
# Out:
# ...
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'ExecuteTime': {'end_time': '2020-02-21T05:04:28.391133Z',
#      'start_time': '2020-02-21T05:04:28.388109Z'},
#     'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-02-21T05:04:49.956474',
#      'end_time': '2020-02-21T05:04:49.966985',
#      'duration': 0.010511,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# the paremeters section\ngender = "male"\nedu = "bachelor\'s degree"'},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-02-21T05:04:49.972486',
#      'end_time': '2020-02-21T05:04:49.984454',
#      'duration': 0.011968,
#      'status': 'completed'}},
#    'execution_count': 2,
#    'source': '# Parameters\ngender = "female"\nedu = "master\'s degree"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
# ...

# %%
pm.execute_notebook('papermill.ipynb',
                    'papermill_output.ipynb',
                    parameters={
                        'gender': "male",
                        'edu': "some college"
                    })
# Out:
# ...
# {'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'ExecuteTime': {'end_time': '2020-02-21T05:04:28.391133Z',
#      'start_time': '2020-02-21T05:04:28.388109Z'},
#     'tags': ['parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-02-21T05:04:54.608046',
#      'end_time': '2020-02-21T05:04:54.618073',
#      'duration': 0.010027,
#      'status': 'completed'}},
#    'outputs': [],
#    'source': '# the paremeters section\ngender = "male"\nedu = "bachelor\'s degree"'},
#   {'cell_type': 'code',
#    'metadata': {'tags': ['injected-parameters'],
#     'papermill': {'exception': False,
#      'start_time': '2020-02-21T05:04:54.622612',
#      'end_time': '2020-02-21T05:04:54.634129',
#      'duration': 0.011517,
#      'status': 'completed'}},
#    'execution_count': 2,
#    'source': '# Parameters\ngender = "male"\nedu = "some college"\n',
#    'outputs': []},
#   {'cell_type': 'code',
#    'execution_count': 3,
# ...
